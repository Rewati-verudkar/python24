# %% [markdown]
# ## list

# %%
lis = []

# %%
l1 = ["red", "yellow", "blue", "white"]

# %%
l2 = ["apple", "orange", "cherry"]

# %%
l3  =l1 + l2

# %%
l2 *3
# Out:
# ['apple',
#  'orange',
#  'cherry',
#  'apple',
#  'orange',
#  'cherry',
#  'apple',
#  'orange',
#  'cherry']

# %%
l3
# Out:
# ['red', 'yellow', 'blue', 'white', 'apple', 'orange', 'cherry']

# %%
l3[3]
# Out:
# 'white'

# %%
l3[-2]
# Out:
# 'orange'

# %%
l3[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 l3[9]
#
# IndexError: list index out of range

# %%
l3[2:]
# Out:
# ['blue', 'white', 'apple', 'orange', 'cherry']

# %%
l3
# Out:
# ['red', 'yellow', 'blue', 'white', 'apple', 'orange', 'cherry']

# %%
l3[:10]
# Out:
# ['red', 'yellow', 'blue', 'white', 'apple', 'orange', 'cherry']

# %%
l3[::-1]
# Out:
# ['cherry', 'orange', 'apple', 'white', 'blue', 'yellow', 'red']

# %%
l3[2] = "pink"

# %%
l3
# Out:
# ['red', 'yellow', 'pink', 'white', 'apple', 'orange', 'cherry']

# %%
l2
# Out:
# ['apple', 'orange', 'cherry']

# %%
l2.append(23)

# %%
l2
# Out:
# ['apple', 'orange', 'cherry', 23]

# %%
l2.append("python")

# %%
l2
# Out:
# ['apple', 'orange', 'cherry', 23, 'python']

# %%
l2.append((1,2,3))

# %%
l2
# Out:
# ['apple', 'orange', 'cherry', 23, 'python', (1, 2, 3)]

# %%
l2.extend(76)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 l2.extend(76)
#
# TypeError: 'int' object is not iterable

# %%
l2.extend("76")

# %%
l2
# Out:
# ['apple', 'orange', 'cherry', 23, 'python', (1, 2, 3), '7', '6']

# %%
l1
# Out:
# ['red', 'yellow', 'blue', 'white']

# %%
l2.extend(l1)

# %%
l2
# Out:
# ['apple',
#  'orange',
#  'cherry',
#  23,
#  'python',
#  (1, 2, 3),
#  '7',
#  '6',
#  'red',
#  'yellow',
#  'blue',
#  'white']

# %%
l2.pop()
# Out:
# 'white'

# %%
l2.pop()
# Out:
# 'yellow'

# %%
l2
# Out:
# ['apple', 'orange', 'cherry', 23, 'python', (1, 2, 3), '7', '6', 'red']

# %%
l2.remove(23)

# %%
l2
# Out:
# ['apple', 'orange', 'cherry', 'python', (1, 2, 3), '7', '6', 'red']

# %%
l2.remove("cherry")

# %%
l2
# Out:
# ['apple', 'orange', 'python', (1, 2, 3), '7', '6', 'red']

# %%
l4 = l2.copy()

# %%
l2
# Out:
# ['apple', 'orange', 'python', (1, 2, 3), '7', '6', 'red']

# %%
l4.clear()

# %%
l4
# Out:
# []

# %%
l2.index("7")
# Out:
# 4

# %%
l2[3]
# Out:
# (1, 2, 3)

# %%
l2
# Out:
# ['apple', 'orange', 'python', (1, 2, 3), '7', '6', 'red']

# %%
l2.insert(1, "java")

# %%
l2
# Out:
# ['apple', 'java', 'orange', 'python', (1, 2, 3), '7', '6', 'red']

# %%
l2.reverse()

# %%
l2
# Out:
# ['red', '6', '7', (1, 2, 3), 'python', 'orange', 'java', 'apple']

# %%
l2.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 l2.sort()
#
# TypeError: '<' not supported between instances of 'tuple' and 'str'

# %%
l5 = [2,3,5,1,7,8,9,2]

# %%
l5.sort()

# %%
l5
# Out:
# [1, 2, 2, 3, 5, 7, 8, 9]

# %%
l1
# Out:
# ['red', 'yellow', 'blue', 'white']

# %%
tuple(l1)
# Out:
# ('red', 'yellow', 'blue', 'white')

# %% [markdown]
# ## Set

# %%
set = {}

# %%
type(s1)
# Out:
# dict

# %%
s1 = {1,2,3,4,2,3,4,5,}

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s1[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 s1[2]
#
# TypeError: 'set' object is not subscriptable

# %%
s1[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 s1[:]
#
# TypeError: 'set' object is not subscriptable

# %%
s1 + s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 s1 + s1
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
s1 * 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 s1 * 2
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
s1[1] = 33
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 s1[1] = 33
#
# TypeError: 'set' object does not support item assignment

# %%
s1 = {1,2,3,4}
s2 = {3,4,5,6}

# %%
s1.add(2.5)

# %%
s1
# Out:
# {1, 2, 2.5, 3, 4, 6}

# %%
s1.update({5})

# %%
s1
# Out:
# {1, 2, 2.5, 3, 4, 5, 6}

# %%
s1.update([7,8])

# %%
s1
# Out:
# {1, 2, 2.5, 3, 4, 5, 6, 7, 8}

# %%
s1.update("c++")

# %%
s1
# Out:
# {'+', 1, 2, 2.5, 3, 4, 5, 6, 7, 8, 'c'}

# %%
s1.pop()
# Out:
# 2.5

# %%
s1
# Out:
# {'+', 5, 6, 7, 8, 'c'}

# %%
s1.remove("+")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 s1.remove("+")
#
# KeyError: '+'

# %%
s1
# Out:
# {5, 6, 7, 8, 'c'}

# %%
s1.discard(7)

# %%
s1
# Out:
# {5, 6, 8, 'c'}

# %%
s1 = {1,2,3,4}
s2 = {3,4,5,6}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.difference(s2)
# Out:
# {1, 2}

# %%
s2.difference(s1)
# Out:
# {5, 6}

# %%
s1.intersection(s2)
# Out:
# {3, 4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1 & s2
# Out:
# {3, 4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s2
# Out:
# {3, 4, 5, 6}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {1, 2}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s2
# Out:
# {3, 4, 5, 6}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {3, 4}

# %%
s3 = {3,4,5,6,7}
s4 = {3,4}

# %%
s3.issubset(s4)
# Out:
# False

# %%
s4.issubset(s3)
# Out:
# True

# %%
s3.issuperset(s4)
# Out:
# True

# %%
s3
# Out:
# {3, 4, 5, 6, 7}

# %%
s5 = frozenset(s3)

# %%
type(s5)
# Out:
# frozenset

# %%
s3
# Out:
# {3, 4, 5, 6, 7}

# %%
4 in s3
# Out:
# True

# %%
s3 is s4
# Out:
# False
